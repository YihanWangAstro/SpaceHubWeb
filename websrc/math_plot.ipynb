# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings(action="once")
from multiprocessing import  Pool


sns.set_style("darkgrid", {'xtick.top': False, 'ytick.right': False,'xtick.bottom': False, 'ytick.left': False,'grid.linestyle': '--','image.cmap': 'viridis','xtick.direction': 'in', 'ytick.direction': 'in'})

COLOR = '#0f1217'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR
plt.rcParams['axes.grid'] = 'True'
plt.rcParams['grid.color'] = COLOR


# @global settings

FIG_DPI      = 1200
FIG_EXT      = '.png'

# @global functions
def savefig(handler,name, fig_ext = FIG_EXT):
    if name != '':
        handler.savefig(name + fig_ext, dpi = FIG_DPI,bbox_inches = 'tight', pad_inches = 0.1, facecolor='#2f363f')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/yihan/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['savefig']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
def draw_func(x,y,name):
    fig = plt.figure(figsize=(3,2))
    ax = fig.add_subplot(1,1,1)
    ax.plot(x,y,color='#5b9dd9',lw=3)
   
    ax.plot(x,y,color='#2f83cc',lw=1)
  
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_facecolor('#2f363f')
    ax.figure.set_facecolor('#2f363f')
    ax.set_frame_on(False)
    savefig(plt,name)

# %%
x=np.linspace(-10,10,1000)
y=np.heaviside(x,0)

draw_func(x,y,'img/math/step')

# %%
x=np.linspace(-10,10,1000)
y=np.sign(x)

draw_func(x,y,'img/math/sign')
